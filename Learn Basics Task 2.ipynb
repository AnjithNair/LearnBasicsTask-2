# %%
import pandas as pd

# %%
ip1 = pd.read_excel(r'C:\Users\Anjith\Downloads\Input_2.xlsx')

# %%
ip1
# Out:
#         Name  id Chapter Tag Concept Test 1 - score  \
# 0    Darshan  34       C8S10                      -
# 1      Durga  35       C8S10                      -
# 2      Idhaz  36       C8S10                      2
# 3    Kishore  37       C8S10                      -
# 4       Mano  38       C8S10                      2
# 5     Nandha  39       C8S10                      -
# 6   Nandhini  40       C8S10                      2
# 7     Rubika  42       C8S10                      3
# 8      Saila  43       C8S10                      2
# 9    Shankar  44       C8S10                      -
# 10     Tarun  45       C8S10                      -
# 11    Thanis  46       C8S10                      -
#
#    Concept Test 1 - time-taken (seconds) Concept Test 1 - answered  \
# 0                                      -                         -
# 1                                      -                         -
# 2                                    125                         5
# ...

# %%
ct1 = ip1.filter(like='Concept Test 1')

ct1["Name"] = ip1["Name"]
ct1["id"] = ip1["id"]
ct1["Chapter Tag"] = ip1["Chapter Tag"]

First_column = ct1.pop("Name")
Sec_colmn = ct1.pop("id")
third_colmn = ct1.pop("Chapter Tag")
ct1.insert(0,"Name",First_column)
ct1.insert(1,"id",Sec_colmn)
ct1.insert(2,"Chapter Tag",third_colmn)
ct1["Test Name"] = "Concept Test 1"
ct1.columns = ['Name','Username','Chapter Tag','score','time taken','answered','correct','wrong','skipped','Test_Name']





ct2 = ip1.filter(like='Concept Test 2')

ct2["Name"] = ip1["Name"]
ct2["id"] = ip1["id"]
ct2["Chapter Tag"] = ip1["Chapter Tag"]

First_column = ct2.pop("Name")
Sec_colmn = ct2.pop("id")
third_colmn = ct2.pop("Chapter Tag")
ct2.insert(0,"Name",First_column)
ct2.insert(1,"id",Sec_colmn)
ct2.insert(2,"Chapter Tag",third_colmn)
ct2["Test Name"] = "Concept Test 2"
ct2.columns = ['Name','Username','Chapter Tag','score','time taken','answered','correct','wrong','skipped','Test_Name']




ct3 = ip1.filter(like='Concept Test 3')

ct3["Name"] = ip1["Name"]
ct3["id"] = ip1["id"]
ct3["Chapter Tag"] = ip1["Chapter Tag"]

First_column = ct3.pop("Name")
Sec_colmn = ct3.pop("id")
third_colmn = ct3.pop("Chapter Tag")
ct3.insert(0,"Name",First_column)
ct3.insert(1,"id",Sec_colmn)
ct3.insert(2,"Chapter Tag",third_colmn)
ct3["Test Name"] = "Concept Test 3"
ct3.columns = ['Name','Username','Chapter Tag','score','time taken','answered','correct','wrong','skipped','Test_Name']






ct4 = ip1.filter(like='Concept Test 4')

ct4["Name"] = ip1["Name"]
ct4["id"] = ip1["id"]
ct4["Chapter Tag"] = ip1["Chapter Tag"]

First_column = ct4.pop("Name")
Sec_colmn = ct4.pop("id")
third_colmn = ct4.pop("Chapter Tag")
ct4.insert(0,"Name",First_column)
ct4.insert(1,"id",Sec_colmn)
ct4.insert(2,"Chapter Tag",third_colmn)
ct4["Test Name"] = "Concept Test 4"
ct4.columns = ['Name','Username','Chapter Tag','score','time taken','answered','correct','wrong','skipped','Test_Name']







ct5 = ip1.filter(like='Concept Test 5')

ct5["Name"] = ip1["Name"]
ct5["id"] = ip1["id"]
ct5["Chapter Tag"] = ip1["Chapter Tag"]

First_column = ct5.pop("Name")
Sec_colmn = ct5.pop("id")
third_colmn = ct5.pop("Chapter Tag")
ct5.insert(0,"Name",First_column)
ct5.insert(1,"id",Sec_colmn)
ct5.insert(2,"Chapter Tag",third_colmn)
ct5["Test Name"] = "Concept Test 5"
ct5.columns = ['Name','Username','Chapter Tag','score','time taken','answered','correct','wrong','skipped','Test_Name']


ctli = [ct1,ct2,ct3,ct4,ct5]
ct = pd.concat(ctli)
Ct = ct[ct.loc[:]!='-'].dropna()
# Out:
# C:\Users\Anjith\AppData\Local\Temp\ipykernel_14804\1240641608.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ct1["Name"] = ip1["Name"]
# C:\Users\Anjith\AppData\Local\Temp\ipykernel_14804\1240641608.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ct1["id"] = ip1["id"]
# C:\Users\Anjith\AppData\Local\Temp\ipykernel_14804\1240641608.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
tt1 = ip1.filter(like='Topic Test 1')

tt1["Name"] = ip1["Name"]
tt1["id"] = ip1["id"]
tt1["Chapter Tag"] = ip1["Chapter Tag"]

First_column = tt1.pop("Name")
Sec_colmn = tt1.pop("id")
third_colmn = tt1.pop("Chapter Tag")
tt1.insert(0,"Name",First_column)
tt1.insert(1,"id",Sec_colmn)
tt1.insert(2,"Chapter Tag",third_colmn)
tt1["Test name"]= "Topic Test 1"
tt1.columns = ['Name','Username','Chapter Tag','score','time taken','answered','correct','wrong','skipped','Test_Name']



tt2 = ip1.filter(like='Topic Test 2')

tt2["Name"] = ip1["Name"]
tt2["id"] = ip1["id"]
tt2["Chapter Tag"] = ip1["Chapter Tag"]

First_column = tt2.pop("Name")
Sec_colmn = tt2.pop("id")
third_colmn = tt2.pop("Chapter Tag")
tt2.insert(0,"Name",First_column)
tt2.insert(1,"id",Sec_colmn)
tt2.insert(2,"Chapter Tag",third_colmn)
tt2["Test name"]= "Topic Test 2"
tt2.columns = ['Name','Username','Chapter Tag','score','time taken','answered','correct','wrong','skipped','Test_Name']



ttli = [tt1,tt2]
tt = pd.concat(ttli)
Tt = tt[tt.loc[:]!="-"].dropna()
# Out:
# C:\Users\Anjith\AppData\Local\Temp\ipykernel_14804\2116512854.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt1["Name"] = ip1["Name"]
# C:\Users\Anjith\AppData\Local\Temp\ipykernel_14804\2116512854.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt1["id"] = ip1["id"]
# C:\Users\Anjith\AppData\Local\Temp\ipykernel_14804\2116512854.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
fct1 = ip1.filter(like ="Full Chapter Test 1")

fct1["Name"] = ip1["Name"]
fct1["id"] = ip1["id"]
fct1["Chapter Tag"] = ip1["Chapter Tag"]

First_column = fct1.pop("Name")
Sec_colmn = fct1.pop("id")
third_colmn = fct1.pop("Chapter Tag")
fct1.insert(0,"Name",First_column)
fct1.insert(1,"id",Sec_colmn)
fct1.insert(2,"Chapter Tag",third_colmn)
fct1["Test_Name"] = "Full Chapter Test 1"
fct1.columns = ['Name','Username','Chapter Tag','score','time taken','answered','correct','wrong','skipped','Test_Name']




fct2 = ip1.filter(like ="Full Chapter Test 2")

fct2["Name"] = ip1["Name"]
fct2["id"] = ip1["id"]
fct2["Chapter Tag"] = ip1["Chapter Tag"]

First_column = fct2.pop("Name")
Sec_colmn = fct2.pop("id")
third_colmn = fct2.pop("Chapter Tag")
fct2.insert(0,"Name",First_column)
fct2.insert(1,"id",Sec_colmn)
fct2.insert(2,"Chapter Tag",third_colmn)
fct2["Test_Name"] = "Full Chapter Test 2"
fct2.columns = ['Name','Username','Chapter Tag','score','time taken','answered','correct','wrong','skipped','Test_Name']

fctli = [fct1,fct2]
fct = pd.concat(fctli)
Fct = fct[fct.loc[:]!= '-'].dropna()
# Out:
# C:\Users\Anjith\AppData\Local\Temp\ipykernel_14804\3412512061.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fct1["Name"] = ip1["Name"]
# C:\Users\Anjith\AppData\Local\Temp\ipykernel_14804\3412512061.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fct1["id"] = ip1["id"]
# C:\Users\Anjith\AppData\Local\Temp\ipykernel_14804\3412512061.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
outputli = [Ct,Tt,Fct]
output = pd.concat(outputli)
out = output.sort_values(["Username","Test_Name"])

# %%
out
# Out:
#        Name  Username Chapter Tag score time taken answered correct wrong  \
# 0   Darshan        34       C8S10     3        187        4       3     1
# 0   Darshan        34       C8S10     3        175        3       3     0
# 0   Darshan        34       C8S10     3         91        4       3     1
# 0   Darshan        34       C8S10     3         84        3       3     0
# 0   Darshan        34       C8S10     3         74        6       3     3
# ..      ...       ...         ...   ...        ...      ...     ...   ...
# 11   Thanis        46       C8S10     2         70        4       2     2
# 11   Thanis        46       C8S10     2        108        5       2     3
# 11   Thanis        46       C8S10     3        183       10       3     7
# 11   Thanis        46       C8S10     7        123       10       7     3
# 11   Thanis        46       C8S10     4         73       10       4     6
#
#    skipped            Test_Name
# 0        1       Concept Test 2
# ...
